# %%
import numpy as np
from astropy.io import fits
from astropy.wcs import WCS
import astropy.units as units
from astropy.utils.exceptions import AstropyWarning
from spectral_cube import SpectralCube

# %%
# !ls ../data/images/
# Out:
# Antennae_North.CO3_2Line.Clean.pcal1.image.mom0.fits
# Antennae_South.CO3_2Line.Clean.pcal1.image.mom0.fits
# CenA.Cont.Clean.image.fits
# M100_12m_CO.image.mom0.pbcor.fits
# M100_combine_CO_cube.image.mom0.pbcor.fits
# OphA_ExtnCambR_F.fits
# Orion.cont.image.fits
# Orion.cont.image.png
# PerA_Extn2MASS_F_Gal.fits
# RhoOphiuchus60.fits
# SDP81_band7_11exec.contR1.image.fits
# TWHydra_CO3_2line.image.mom0.fits
# VYCMa_658_contap4.clean.fits
# calibrated_final_cont_image.image.fits
# dendro.fits
# dendro_old.fits
# orion_12CO_mom0.png
# perseus60.fits
# result-ngc3256_cont.image.fits
# result-ngc3256_cont_sc1.image.fits

# %%
fits_path = "../data/images/Antennae_North.CO3_2Line.Clean.pcal1.image.mom0.fits"

# %%
cube = SpectralCube.read(fits_path)
hdu = cube.hdu
data = cube.base
wcs = WCS(hdu.header)
# Out:
# /Users/martin/anaconda3/lib/python3.6/site-packages/spectral_cube/cube_utils.py:114: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   stokes_arrays[stokes_names[i_stokes]] = array[array_slice]
# /Users/martin/anaconda3/lib/python3.6/site-packages/spectral_cube/cube_utils.py:445: UserWarning: Could not parse unit JY/BEAM.KM/S
#   warnings.warn("Could not parse unit {0}".format(bunit))
# /Users/martin/anaconda3/lib/python3.6/site-packages/spectral_cube/spectral_cube.py:2031: UserWarning: Cube is a Stokes cube, returning spectral cube for I component
#   warnings.warn("Cube is a Stokes cube, "

# %%
(cube.spectral_axis).to(units.GHz)
# Out:
# <Quantity [344.03120956] GHz>

# %%
hdu.header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                  500
# NAXIS2  =                  500
# NAXIS3  =                    1
# BMAJ    =   0.0003351213203536
# BMIN    =   0.0001827486852805
# BPA     =       88.25967407227
# BTYPE   = 'Intensity'
# OBJECT  = 'NGC4038 - Antennae North'
# BUNIT   = 'JY/BEAM.KM/S'       /Brightness (pixel) unit
# PC001001=   1.000000000000E+00
# PC002001=   0.000000000000E+00
# PC003001=   0.000000000000E+00
# PC004001=   0.000000000000E+00
# PC001002=   0.000000000000E+00
# PC002002=   1.000000000000E+00
# PC003002=   0.000000000000E+00
# PC004002=   0.000000000000E+00
# PC001003=   0.000000000000E+00
# PC002003=   0.000000000000E+00
# PC003003=   1.000000000000E+00
# PC004003=   0.000000000000E+00
# PC001004=   0.000000000000E+00
# PC002004=   0.000000000000E+00
# PC003004=   0.000000000000E+00
# ...

# %% [markdown]
# ***

# %%
# !ls ../data/images/
# Out:
# Antennae_North.CO3_2Line.Clean.pcal1.image.mom0.fits
# Antennae_South.CO3_2Line.Clean.pcal1.image.mom0.fits
# CenA.Cont.Clean.image.fits
# M100_12m_CO.image.mom0.pbcor.fits
# M100_combine_CO_cube.image.mom0.pbcor.fits
# OphA_ExtnCambR_F.fits
# Orion.cont.image.fits
# Orion.cont.image.png
# PerA_Extn2MASS_F_Gal.fits
# RhoOphiuchus60.fits
# SDP81_band7_11exec.contR1.image.fits
# TWHydra_CO3_2line.image.mom0.fits
# VYCMa_658_contap4.clean.fits
# calibrated_final_cont_image.image.fits
# dendro.fits
# dendro_old.fits
# orion_12CO_mom0.png
# perseus60.fits
# result-ngc3256_cont.image.fits
# result-ngc3256_cont_sc1.image.fits

# %%
fits_path = "../data/images/result-ngc3256_cont.image.fits"

# %%
cube = SpectralCube.read(fits_path)
hdu = cube.hdu
data = cube.base
wcs = WCS(hdu.header)
# Out:
# /Users/martin/anaconda3/lib/python3.6/site-packages/spectral_cube/cube_utils.py:114: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   stokes_arrays[stokes_names[i_stokes]] = array[array_slice]
# /Users/martin/anaconda3/lib/python3.6/site-packages/spectral_cube/spectral_cube.py:2031: UserWarning: Cube is a Stokes cube, returning spectral cube for I component
#   warnings.warn("Cube is a Stokes cube, "

# %%
(cube.spectral_axis).to(units.GHz)
# Out:
# <Quantity [107.36629386] GHz>

# %%
hdu.header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                  100
# NAXIS2  =                  100
# NAXIS3  =                    1
# BMAJ    =     0.00188067846828
# BMIN    =     0.00128028790156
# BPA     =       50.48292160034
# BTYPE   = 'Intensity'
# OBJECT  = 'NGC3256 '
# BUNIT   = 'beam-1 Jy'          / Brightness (pixel) unit
# PC001001=   1.000000000000E+00
# PC002001=   0.000000000000E+00
# PC003001=   0.000000000000E+00
# PC004001=   0.000000000000E+00
# PC001002=   0.000000000000E+00
# PC002002=   1.000000000000E+00
# PC003002=   0.000000000000E+00
# PC004002=   0.000000000000E+00
# PC001003=   0.000000000000E+00
# PC002003=   0.000000000000E+00
# PC003003=   1.000000000000E+00
# PC004003=   0.000000000000E+00
# PC001004=   0.000000000000E+00
# PC002004=   0.000000000000E+00
# PC003004=   0.000000000000E+00
# ...

# %%
fits_path = "../data/images/Antennae_North.CO3_2Line.Clean.pcal1.image.mom0.fits"

# %%
cube = SpectralCube.read(fits_path)
hdu = cube.hdu
data = cube.base
wcs = WCS(hdu.header)
# Out:
# /Users/martin/anaconda3/lib/python3.6/site-packages/spectral_cube/cube_utils.py:114: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   stokes_arrays[stokes_names[i_stokes]] = array[array_slice]
# /Users/martin/anaconda3/lib/python3.6/site-packages/spectral_cube/cube_utils.py:445: UserWarning: Could not parse unit JY/BEAM.KM/S
#   warnings.warn("Could not parse unit {0}".format(bunit))
# /Users/martin/anaconda3/lib/python3.6/site-packages/spectral_cube/spectral_cube.py:2031: UserWarning: Cube is a Stokes cube, returning spectral cube for I component
#   warnings.warn("Cube is a Stokes cube, "

# %%
hdu.header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                  500
# NAXIS2  =                  500
# NAXIS3  =                    1
# BMAJ    =   0.0003351213203536
# BMIN    =   0.0001827486852805
# BPA     =       88.25967407227
# BTYPE   = 'Intensity'
# OBJECT  = 'NGC4038 - Antennae North'
# BUNIT   = 'JY/BEAM.KM/S'       /Brightness (pixel) unit
# PC001001=   1.000000000000E+00
# PC002001=   0.000000000000E+00
# PC003001=   0.000000000000E+00
# PC004001=   0.000000000000E+00
# PC001002=   0.000000000000E+00
# PC002002=   1.000000000000E+00
# PC003002=   0.000000000000E+00
# PC004002=   0.000000000000E+00
# PC001003=   0.000000000000E+00
# PC002003=   0.000000000000E+00
# PC003003=   1.000000000000E+00
# PC004003=   0.000000000000E+00
# PC001004=   0.000000000000E+00
# PC002004=   0.000000000000E+00
# PC003004=   0.000000000000E+00
# ...

# %%
(cube.spectral_axis).to(units.GHz)
# Out:
# <Quantity [344.03120956] GHz>

# %% [markdown]
# ***

# %%
# !ls ../data/cubes/
# Out:
# ALMA00000001.fits
# ALMA00000095.fits
# Antennae_North.CO2_1Line.Clean.image.fits
# CenA.CO2_1Line.Clean.image.fits
# IRAS16293_Methanol_image.pbcor.fits
# M100_12m_CO.image.fits
# M100_combine_CO_cube.image.fits
# Orion.methanol.cbc.contsub.image.fits
# VYCMa_658.0_H2O.clean.image.fits

# %%
fits_path = "../data/cubes/Orion.methanol.cbc.contsub.image.fits"

# %%
cube = SpectralCube.read(fits_path)
hdu = cube.hdu
data = cube.base
wcs = WCS(hdu.header)
# Out:
# /Users/martin/anaconda3/lib/python3.6/site-packages/spectral_cube/cube_utils.py:114: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   stokes_arrays[stokes_names[i_stokes]] = array[array_slice]
# /Users/martin/anaconda3/lib/python3.6/site-packages/spectral_cube/spectral_cube.py:2031: UserWarning: Cube is a Stokes cube, returning spectral cube for I component
#   warnings.warn("Cube is a Stokes cube, "

# %%
np.median((cube.spectral_axis).to(units.GHz))
# Out:
# <Quantity 229.7533946 GHz>

# %%
hdu.header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                  100
# NAXIS2  =                  100
# NAXIS3  =                   41
# BMAJ    =   0.0005261126491759
# BMIN    =   0.0003823845585187
# BPA     =       164.8626861572
# BTYPE   = 'Intensity'
# OBJECT  = 'Orion KL'
# BUNIT   = 'beam-1 Jy'          / Brightness (pixel) unit
# PC001001=   1.000000000000E+00
# PC002001=   0.000000000000E+00
# PC003001=   0.000000000000E+00
# PC004001=   0.000000000000E+00
# PC001002=   0.000000000000E+00
# PC002002=   1.000000000000E+00
# PC003002=   0.000000000000E+00
# PC004002=   0.000000000000E+00
# PC001003=   0.000000000000E+00
# PC002003=   0.000000000000E+00
# PC003003=   1.000000000000E+00
# PC004003=   0.000000000000E+00
# PC001004=   0.000000000000E+00
# PC002004=   0.000000000000E+00
# PC003004=   0.000000000000E+00
# ...

# %% [markdown]
# ***

# %%
# !ls ../data/cubes/
# Out:
# ALMA00000001.fits
# ALMA00000095.fits
# Antennae_North.CO2_1Line.Clean.image.fits
# CenA.CO2_1Line.Clean.image.fits
# IRAS16293_Methanol_image.pbcor.fits
# M100_12m_CO.image.fits
# M100_combine_CO_cube.image.fits
# Orion.methanol.cbc.contsub.image.fits
# VYCMa_658.0_H2O.clean.image.fits

# %%
fits_path = "../data/cubes/ALMA00000095.fits"

# %%
cube = SpectralCube.read(fits_path)
hdu = cube.hdu
data = cube.base
wcs = WCS(hdu.header)
# Out:
# /Users/martin/anaconda3/lib/python3.6/site-packages/spectral_cube/cube_utils.py:114: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   stokes_arrays[stokes_names[i_stokes]] = array[array_slice]
# /Users/martin/anaconda3/lib/python3.6/site-packages/spectral_cube/spectral_cube.py:2031: UserWarning: Cube is a Stokes cube, returning spectral cube for I component
#   warnings.warn("Cube is a Stokes cube, "

# %%
hdu.header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                  512
# NAXIS2  =                  512
# NAXIS3  =                  140
# BMAJ    =   0.0001809324986405
# BMIN    =   0.0001176434093051
# BPA     =        92.8176574707
# BTYPE   = 'Intensity'
# OBJECT  = 'HD163296'
# BUNIT   = 'beam-1 Jy'          / Brightness (pixel) unit
# PC001001=   1.000000000000E+00
# PC002001=   0.000000000000E+00
# PC003001=   0.000000000000E+00
# PC004001=   0.000000000000E+00
# PC001002=   0.000000000000E+00
# PC002002=   1.000000000000E+00
# PC003002=   0.000000000000E+00
# PC004002=   0.000000000000E+00
# PC001003=   0.000000000000E+00
# PC002003=   0.000000000000E+00
# PC003003=   1.000000000000E+00
# PC004003=   0.000000000000E+00
# PC001004=   0.000000000000E+00
# PC002004=   0.000000000000E+00
# PC003004=   0.000000000000E+00
# ...

# %%
np.median((cube.spectral_axis).to(units.GHz))
# Out:
# <Quantity 345.79005549 GHz>
