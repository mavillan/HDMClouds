# %% [markdown]
# # OrionKL test with method 1

# %%
# %matplotlib inline

import os
import sys
import copy
import numpy as np

# filtering Astropy warnings
import warnings
from astropy.utils.exceptions import AstropyWarning
warnings.simplefilter('ignore', category=AstropyWarning)

# autoreload user modules functionality
# %load_ext autoreload
# %autoreload 2

sys.path.append('../lib/')
from hdmclouds_v1 import *
from utils import *
from graph import *
from preprocessing import *
from gmr import *

from ipywidgets import interact, interactive, fixed, FloatSlider, IntSlider
from IPython.display import display

import matplotlib
import matplotlib.pyplot as plt; plt.show()
matplotlib.rcParams.update({'font.size': 20})

#from pycupid import *

save_path = "/Users/martin/Dropbox/Aplicaciones/ShareLaTeX/HDMC-3rd_mnras_submission/figures/"

# %%
fits_path = '../data/images/Orion.cont.image.fits'
#fits_path = '../data/images/OphA_ExtnCambR_F.fits'
#fits_path = '../data/images/PerA_Extn2MASS_F_Gal.fits'
#fits_path = '../data/images/RhoOphiuchus60.fits'
#fits_path = '../data/images/perseus60.fits'
#fits_path = '../data/SCIMES/orion_12CO_mom0.fits'

data,wcs,hdu,spec = load_data(fits_path)
base_level = estimate_rms(data)
image_plot(data, wcs=wcs, unit=hdu.header["BUNIT"])
# Out:
# /Users/martin/anaconda3/lib/python3.6/site-packages/spectral_cube/cube_utils.py:114: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   stokes_arrays[stokes_names[i_stokes]] = array[array_slice]

# %%
preprocessing(data, wcs)
# Out:
# interactive(children=(FloatSlider(value=0.10237737624469602, description='back_level', max=0.20475475248939204…

# %%
#%%prun -s tottime -q -l 30 -T gmr_v1.prof
hdmc = HDMClouds(data, back_level=0.089, wcs=wcs, verbose=True, n_gaussians=200, gmr_neighbors=64)
# Out:
# [INFO] Number of pixels with significant emission: 749
# [INFO] Level of compression: 26.702269692923895%
# [INFO] Number of ICEs: 3
# Isolated Cloud Entity A: 47 pixels of significant emission.
# (47, 46)
# (47, 46)
# (24, 23)
# (24, 23)
# Isolated Cloud Entity B: 508 pixels of significant emission.
# (508, 64)
# (508, 64)
# (270, 64)
# (270, 64)
# Isolated Cloud Entity C: 194 pixels of significant emission.
# (194, 64)
# (194, 64)
# (102, 64)
# (102, 64)
# ####################################################################################################

# %%
hdmc.get_residual_stats();
# Out:
# RESIDUAL STATS
# RMS of residual: 0.01809039976162622
# Inf norm of residual: 0.22393295351366727
# Variance of residual: 0.00031575371643782427
# Normalized flux addition: 0.310133708455428
# Normalized flux lost: 0.006898184234022667

# %%
print(open('gmr_v1.prof', 'r').read())
# Out:
#          1461577 function calls (1405127 primitive calls) in 3.887 seconds
#
#    Ordered by: internal time
#    List reduced from 3735 to 30 due to restriction <30>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      2621    0.429    0.000    0.430    0.000 ffi.py:105(__call__)
#         8    0.286    0.036    0.286    0.036 {built-in method matplotlib._png.write_png}
#       167    0.209    0.001    0.209    0.001 {method 'acquire' of '_thread.lock' objects}
#         1    0.120    0.120    0.120    0.120 {sklearn.cluster._dbscan_inner.dbscan_inner}
#       648    0.080    0.000    0.216    0.000 gmr.py:263(radius_search)
#       496    0.078    0.000    0.078    0.000 {method 's2p' of 'astropy.wcs.Wcsprm' objects}
#     59279    0.077    0.000    0.078    0.000 {built-in method numpy.core.multiarray.array}
#        26    0.075    0.003    0.079    0.003 {method 'query_radius' of 'sklearn.neighbors.ball_tree.BinaryTree' objects}
#       480    0.072    0.000    0.072    0.000 {method 'p2s' of 'astropy.wcs.Wcsprm' objects}
#        16    0.069    0.004    0.070    0.004 {built-in method matplotlib._image.resample}
#       651    0.061    0.000    0.061    0.000 gmr.py:286(update_structs)
#      5894    0.061    0.000    0.061    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     42666    0.055    0.000    0.101    0.000 shape_base.py:11(atleast_1d)
# 170555/170513    0.045    0.000    0.054    0.000 {built-in method builtins.isinstance}
#         6    0.042    0.007    1.648    0.275 gmr.py:330(reduce_mixture)
# 34840/15367    0.040    0.000    0.136    0.000 {method 'format' of 'str' objects}
#       315    0.036    0.000    0.036    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
#       114    0.035    0.000    0.040    0.000 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#         8    0.035    0.004    0.036    0.004 {method 'draw_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#       929    0.026    0.000    0.026    0.000 {built-in method numpy.core.multiarray.concatenate}
#      1314    0.026    0.000    0.038    0.000 function_base.py:4065(delete)
#      1855    0.026    0.000    0.072    0.000 instructions.py:63(__init__)
#        98    0.024    0.000    0.028    0.000 linalg.py:1140(eig)
#       480    0.024    0.000    0.205    0.000 transforms.py:143(transform)
#         3    0.022    0.007    1.865    0.622 hdmclouds_v1.py:651(__init__)
#      6082    0.022    0.000    0.074    0.000 instructions.py:14(__init__)
#        64    0.021    0.000    0.048    0.001 coordinate_helpers.py:622(_compute_ticks)
# 13285/2890    0.021    0.000    0.033    0.000 ir.py:157(_rec_list_vars)
#        16    0.021    0.001    0.021    0.001 {method 'take' of 'numpy.ndarray' objects}
#       697    0.020    0.000    0.120    0.000 shape_base.py:283(<listcomp>)

# %% [markdown]
# ***

# %%
# %%prun -s tottime -q -l 30 -T hdmc_m1.prof
hdmc.build_gmr()
# Out:
# ---------------------------------------------
# Building GM for Isolated Cloud Entity A
# ---------------------------------------------
# RESIDUAL STATS
# RMS of residual: 0.013748543172773416
# Inf norm of residual: 0.04201843329272674
# Variance of residual: 0.00015497429400259947
# Normalized flux addition: 0.1558732970657786
# Normalized flux lost: 0.0453557035839369
#
#
# ---------------------------------------------
# Building GM for Isolated Cloud Entity B
# ---------------------------------------------
# RESIDUAL STATS
# RMS of residual: 0.016687551936010653
# Inf norm of residual: 0.06352986039821432
# Variance of residual: 0.00025293311110887275
# Normalized flux addition: 0.04645412205963414
# Normalized flux lost: 0.019340302022013884
#
#
# ---------------------------------------------
# Building GM for Isolated Cloud Entity C
# ---------------------------------------------
# RESIDUAL STATS
# RMS of residual: 0.009490591871949011
# Inf norm of residual: 0.030312741844610094
# Variance of residual: 7.938069355313798e-05
# Normalized flux addition: 0.06897345659104528
# Normalized flux lost: 0.025841567676926764
#
#
#
# *** Profile printout saved to text file 'hdmc_m1.prof'.

# %%
hdmc.get_residual_stats();
# Out:
# RESIDUAL STATS
# RMS of residual: 0.004124008401252254
# Inf norm of residual: 0.06353236207783994
# Variance of residual: 1.6883224205941438e-05
# Normalized flux addition: 0.05221646286854538
# Normalized flux lost: 0.020712743406845622

# %%
print("Elapsed time {0}".format(hdmc.elapsed_time))
# Out:
# Elapsed time 49.171265840530396

# %%
w,sig = hdmc.get_params()

print("PARAMETERS VARIATION:")
print("w variation: ",np.max(np.abs(hdmc.w0-w)))
print("sig variation: ",np.max(np.abs(hdmc.sig0-sig)))
# Out:
# PARAMETERS VARIATION:
# w variation:  0.20758761250745325
# sig variation:  0.0053018628196800435

# %% [markdown]
# #### Profiling results

# %%
print(open('hdmc_m1.prof', 'r').read())
# Out:
#          461534 function calls in 49.171 seconds
#
#    Ordered by: internal time
#    List reduced from 109 to 30 due to restriction <30>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    153423   39.720    0.000   39.720    0.000 {fgm_eval.gm_eval2d_2}
#         3    4.288    1.429   49.156   16.385 {built-in method scipy.optimize._minpack._lmdif}
#     76710    2.965    0.000   44.871    0.001 hdmclouds_v1.py:971(F)
#     76716    1.560    0.000    1.560    0.000 utils.py:132(sig_mapping)
#     76715    0.599    0.000    0.599    0.000 {built-in method numpy.core.multiarray.concatenate}
#     76728    0.029    0.000    0.029    0.000 {built-in method builtins.len}
#         2    0.004    0.002    0.004    0.002 {built-in method numpy.core.multiarray.dot}
#         1    0.002    0.002    0.002    0.002 basic.py:907(inv)
#         2    0.001    0.001    0.001    0.001 {built-in method numpy.core.multiarray.arange}
#        64    0.001    0.000    0.001    0.000 socket.py:334(send)
#         1    0.000    0.000    0.000    0.000 {method 'outer' of 'numpy.ufunc' objects}
#        60    0.000    0.000    0.002    0.000 iostream.py:382(write)
#        64    0.000    0.000    0.001    0.000 iostream.py:195(schedule)
#        22    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         3    0.000    0.000    0.003    0.001 hdmclouds_v1.py:899(get_residual_stats)
#         3    0.000    0.000   49.167   16.389 minpack.py:265(leastsq)
#        30    0.000    0.000    0.002    0.000 {built-in method builtins.print}
#        64    0.000    0.000    0.000    0.000 threading.py:1104(is_alive)
#         3    0.000    0.000    0.000    0.000 _methods.py:91(_var)
#        18    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000   49.171   49.171 hdmclouds_v1.py:445(build_gmr)
#        15    0.000    0.000    0.000    0.000 fromnumeric.py:64(_wrapreduction)
#         3    0.000    0.000   49.167   16.389 hdmclouds_v1.py:1001(build_gmr)
#        64    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#        60    0.000    0.000    0.000    0.000 iostream.py:307(_is_master_process)
#         3    0.000    0.000   49.167   16.389 _root.py:212(_root_leastsq)
#        64    0.000    0.000    0.000    0.000 threading.py:1062(_wait_for_tstate_lock)
#        60    0.000    0.000    0.001    0.000 iostream.py:320(_schedule_flush)
#         3    0.000    0.000    0.003    0.001 minpack.py:25(_check_func)
#         3    0.000    0.000    0.000    0.000 utils.py:28(estimate_rms)

# %% [markdown]
# ***

# %% [markdown]
# ### Building the hierarchical tree

# %%
hdmc.build_hierarchical_tree(htree_algo="KL", n_neighbors=20)
#hdmc.build_hierarchical_tree()
# Out:
# Building the hierarchical tree for Isolated Cloud Entity A
# DONE
#
# Building the hierarchical tree for Isolated Cloud Entity B
# DONE
#
# Building the hierarchical tree for Isolated Cloud Entity C
# DONE

# %%
hdmc.visualize()
# Out:
# interactive(children=(Text(value='', description='split'), Text(value='', description='join1'), Text(value='',…

# %%
gp.ce_plot(hdmc, wcs=hdmc.wcs)

# %%
hdmc.compute_stats()
# Out:
#      Flux [Jy/Beam]   Right Ascension       Declination
# A-0        0.940746  83deg48m29.9324s    -5deg22m44.94s
# B-0       57.166166   83deg48m37.336s  -5deg22m32.3176s
# C-0        6.654866  83deg48m31.5312s  -5deg22m28.7397s

# %% [markdown]
# ***
#
# ## Comparison with `clumpfind` and `fellwalker`

# %%
from pycupid import clumpfind,fellwalker


def compute_caa_stats(data, caa, wcs):
    stats = {}

    for i in range(caa.min()+1, caa.max()+1):
        values = data[caa==i]
        xpos,ypos = np.where(caa==i)

        flux = np.sum(values)
        x_centroid = np.sum(xpos*values)/np.sum(values)
        y_centroid = np.sum(ypos*values)/np.sum(values)

        wx_centroid,wy_centroid = wcs.wcs_pix2world(x_centroid,y_centroid,0)

        stats["CE {0}".format(i)] = (flux, (x_centroid,y_centroid), (wx_centroid,wy_centroid))


    stats = pd.DataFrame.from_dict(stats, orient="index", columns=["Flux [Jy/Beam]", "Centroid Position [pix]", "Centroid Position (ra-dec) [deg]"])   

    display(stats)
    return stats


def caa_show(data, caa, save_path=None, wcs=None):
    bd_map = boundary_map_caa(caa).T
    colors = plt.cm.rainbow(np.linspace(0., 1., caa.max()))
    
    cmap = plt.cm.gray_r
    norm = plt.Normalize(data.min(), data.max())
    rgba = cmap(norm(data))
    
    m,n = data.shape
    for i in range(m):
        for j in range(n):
            if bd_map[i,j]==0: continue
            rgba[i,j,:] = colors[bd_map[i,j]-1]

    patches = []
    for i,color in enumerate(colors):
        colors[bd_map[i,j]-1]
        patches.append(mpatches.Patch(color=color, label='CE {0}'.format(i+1)))

    fig = plt.figure(figsize=(8,8))
    if wcs is not None: fig.gca(projection=wcs)
    im = plt.imshow(rgba)
    plt.grid()
    if wcs is not None:
        plt.xlabel(umap[wcs.axis_type_names[0]])
        plt.ylabel(umap[wcs.axis_type_names[1]])
    else:
        plt.tick_params(labelbottom=False, labelleft=False)
    ax = plt.gca()
    ax.invert_yaxis()
    if save_path is not None:
        plt.savefig(save_path, format='eps', dpi=150, bbox_inches='tight')
    #if wcs is not None:
        #cbar = plt.colorbar(im, ax=ax, pad=0.01, aspect=30)
    ax.set_aspect('auto')
    plt.legend(handles=patches)
    plt.show()

# %% [markdown]
# ***
# ### `clumpfind`

# %%
#out_cf = clumpfind(data, 0.5*base_level)
out_cf = clumpfind(data, 0.078)
out_cf[out_cf==out_cf.min()] = 0.

caa_show(data, out_cf, wcs=wcs)

# %%
compute_caa_stats(data, out_cf, wcs);
# Out:
#       Flux [Jy/Beam]                   Centroid Position [pix]  \
# CE 1       47.263725  (45.102418348646694, 55.110800500659856)
# CE 2       63.512123   (58.75269896603537, 43.558794516594915)
# CE 3        5.147349    (60.02130581784532, 62.89499710792854)
#
#              Centroid Position (ra-dec) [deg]
# CE 1  (83.81033824649124, -5.375821021923468)
# CE 2  (83.80881484605455, -5.377104577610403)
# CE 3  (83.80867327066305, -5.374956110414155)

# %% [markdown]
# ***
# ### `Fellwalker`

# %%
#out_fw = fellwalker(data, 0.5*base_level)
out_fw = fellwalker(data, 0.078)
out_fw[out_fw==out_fw.min()] = 0.

caa_show(data, out_fw, wcs=wcs)

# %%
compute_caa_stats(data, out_fw, wcs);
# Out:
#       Flux [Jy/Beam]                   Centroid Position [pix]  \
# CE 1       50.195412   (45.665768954545506, 54.56304219068273)
# CE 2       49.184555    (60.03908211413193, 43.62341974234582)
# CE 3        4.008535  (59.995116623768396, 63.916111878214366)
# CE 4       -0.134510   (64.38228471820102, 23.446268155351156)
#
#               Centroid Position (ra-dec) [deg]
# CE 1   (83.81027537549518, -5.375881884010656)
# CE 2  (83.80867128285561, -5.3770973967846585)
# CE 3   (83.80867619363268, -5.374842653222719)
# CE 4   (83.80818656590594, -5.379339301442377)

# %% [markdown]
# ***
